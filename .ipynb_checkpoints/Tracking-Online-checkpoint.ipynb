# %%
from gen_config import *
# Out:
# =========================import option=========================
# model_path: ./models/rt-mdnet.pth
# result_path: ./result/
# ===============================================================
# use_gpu: True
# img_size: 107
# padding: 1.2
# jitter: True
# adaptive_align: True
# batch_pos: 32
# batch_neg: 96
# batch_neg_cand: 1024
# batch_test: 256
# n_samples: 256
# trans_f: 0.6
# scale_f: 1.05
# trans_f_expand: 1.4
# n_bbreg: 1000
# overlap_bbreg: [0.6, 1]
# scale_bbreg: [1, 2]
# lr_init: 0.0001
# maxiter_init: 50
# n_pos_init: 500
# n_neg_init: 5000
# overlap_pos_init: [0.7, 1]
# overlap_neg_init: [0, 0.5]
# lr_update: 0.0003
# maxiter_update: 15
# n_pos_update: 50
# n_neg_update: 200
# overlap_pos_update: [0.7, 1]
# overlap_neg_update: [0, 0.3]
# success_thr: 0.0
# n_frames_short: 20
# n_frames_long: 100
# long_interval: 10
# w_decay: 0.0005
# momentum: 0.9
# grad_clip: 10
# lr_mult: {'fc6': 10}
# ft_layers: ['fc']
# set_type: OTB
# visual_log: True
# visualize: False

# %%
###set opts###

np.random.seed(123321)
torch.manual_seed(456654)
torch.cuda.manual_seed(789987)

tracker_name = 'RT-MDNet_'# 後續可以加上model的名字
opts['result_path'] = opts['result_path'] + tracker_name + '/'
save_fig_path = opts['result_path'] +tracker_name + '_fig/'
print(opts['result_path'])
print(save_fig_path)
# Out:
# ./result/RT-MDNet_/
# ./result/RT-MDNet_/RT-MDNet__fig/

# %%
### run all ###
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
tb_100 = open('/home/wilsontsang/tracking_benchmark/dataset/ALL_OTB.txt')  # open the file as a file
seq_list = tb_100.readlines()
names = sorted([x.split('\t')[0].strip() for x in seq_list])
seq_home = dataset_path + opts['set_type']

iou_list=[]
fps_list=dict()
bb_result= dict()
result = dict()

iou_list_nobb = []
bb_result_nobb = dict()
for num, seq in enumerate(names):
    if num<-1:
        continue
    seq_path = os.path.join(seq_home, seq)
    if not os.path.exists(opts['result_path']):
        os.mkdir(opts['result_path'])
    save_path = opts['result_path'] + seq +'_'+tracker_name + '.mat'
    img_list, gt = genConfig(seq_path, opts['set_type'])
    
    if not os.path.exists(save_path): # avoid repeatly run
        
            iou_result, result_bb, fps, result_nobb = run_mdnet(img_list, gt[0], gt, seq = seq, savefig_dir=save_fig_path, display=opts['visualize'])

            enable_frameNum = 0.
            for iidx in range(len(iou_result)):
                if (math.isnan(iou_result[iidx])==False): 
                    enable_frameNum += 1.
                else:
                    ## gt is not alowed
                    iou_result[iidx] = 0.

            iou_list.append(iou_result.sum()/enable_frameNum)
            # bb_result[seq] = result_bb
            fps_list[seq]=fps

            # bb_result_nobb[seq] = result_nobb
            # TODO: what is iou_result and mIoU
            print '{} {} : {} , total mIoU:{}, fps:{}'.format(num,seq,iou_result.mean(), sum(iou_list)/len(iou_list),sum(fps_list.values())/len(fps_list))

        ### convert to store .mat
        # result['bb_result']=bb_result
        # result['fps']=fps_list
        # result['bb_result_nobb']=bb_result_nobb
        # np.save(opts['result_path'],result)
        # Tab indent
            res = {}
            res['res'] = result_bb.round().tolist()
            res['type'] = 'rect'
            res['fps'] = sum(fps_list.values())/len(fps_list)
            res['len'] = len(result_bb)
            A = np.zeros((1,), dtype=np.object)
            A[0] = res
            scipy.io.savemat(save_path, {'results': A})
# Out:
# Basketball
# ./modules/model.py:166: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#
# Frame 241/725, Overlap 0.779, Score 17.068, Time 0.020
# Frame 242/725, Overlap 0.758, Score 17.226, Time 0.020
# Frame 243/725, Overlap 0.783, Score 17.555, Time 0.019
# Frame 244/725, Overlap 0.769, Score 18.303, Time 0.019
# Frame 245/725, Overlap 0.824, Score 16.435, Time 0.019
# Frame 246/725, Overlap 0.801, Score 16.370, Time 0.020
# Frame 247/725, Overlap 0.820, Score 17.084, Time 0.020
# Frame 248/725, Overlap 0.819, Score 15.504, Time 0.020
# Frame 249/725, Overlap 0.798, Score 17.295, Time 0.021
# Frame 250/725, Overlap 0.782, Score 16.810, Time 0.101
# Frame 251/725, Overlap 0.719, Score 17.240, Time 0.020
# Frame 252/725, Overlap 0.746, Score 16.378, Time 0.021
# Frame 253/725, Overlap 0.746, Score 15.692, Time 0.019
# Frame 254/725, Overlap 0.696, Score 14.946, Time 0.021
# Frame 255/725, Overlap 0.715, Score 16.399, Time 0.020
# Frame 256/725, Overlap 0.661, Score 15.586, Time 0.019
# Frame 257/725, Overlap 0.643, Score 14.826, Time 0.021
# Frame 258/725, Overlap 0.626, Score 15.706, Time 0.019
# Frame 259/725, Overlap 0.617, Score 15.658, Time 0.020
# Frame 260/725, Overlap 0.564, Score 17.218, Time 0.098
# Frame 261/725, Overlap 0.571, Score 10.966, Time 0.019
# Frame 262/725, Overlap 0.547, Score 10.942, Time 0.020
# Frame 263/725, Overlap 0.573, Score 11.194, Time 0.019
# Frame 264/725, Overlap 0.568, Score 11.945, Time 0.019
# Frame 265/725, Overlap 0.573, Score 11.720, Time 0.019
# Frame 266/725, Overlap 0.571, Score 11.283, Time 0.019
# Frame 267/725, Overlap 0.547, Score 11.208, Time 0.020
# Frame 268/725, Overlap 0.573, Score 10.030, Time 0.028
# Frame 269/725, Overlap 0.576, Score 11.359, Time 0.153
# Frame 270/725, Overlap 0.611, Score 11.265, Time 0.141
# Frame 271/725, Overlap 0.573, Score 6.943, Time 0.019
# Frame 272/725, Overlap 0.598, Score 6.576, Time 0.021
# Frame 273/725, Overlap 0.582, Score 6.962, Time 0.020
# Frame 274/725, Overlap 0.592, Score 6.934, Time 0.021
# Frame 275/725, Overlap 0.612, Score 6.365, Time 0.020
# Frame 276/725, Overlap 0.590, Score 6.256, Time 0.028
# Frame 277/725, Overlap 0.604, Score 6.121, Time 0.019
# Frame 278/725, Overlap 0.605, Score 6.149, Time 0.021
# Frame 279/725, Overlap 0.588, Score 5.544, Time 0.021
# Frame 280/725, Overlap 0.594, Score 5.389, Time 0.095
# Frame 281/725, Overlap 0.581, Score 5.827, Time 0.019
# Frame 282/725, Overlap 0.556, Score 5.307, Time 0.020
# Frame 283/725, Overlap 0.549, Score 5.651, Time 0.020
# Frame 284/725, Overlap 0.568, Score 5.774, Time 0.019
# Frame 285/725, Overlap 0.566, Score 5.954, Time 0.020
# Frame 286/725, Overlap 0.570, Score 6.442, Time 0.019
# Frame 287/725, Overlap 0.595, Score 6.694, Time 0.020
# Frame 288/725, Overlap 0.614, Score 7.176, Time 0.019
# Frame 289/725, Overlap 0.630, Score 7.214, Time 0.019
